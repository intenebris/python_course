# %% [markdown]
# **Анализ расходов по возрасту.**
# Постройте линейный график, где по оси X будет отображаться возраст (age), а по оси Y —балл по расходам (spending_score). Этот график поможет визуализировать, как изменяются расходы в зависимости от возраста сотрудников. Проанализируйте тренды и выявите возможные закономерности.

# %%
# Библиотека для работы с табличными данными
import pandas as pd
# Библиотеки для визуализации
import seaborn as sns

# %%
# Начнем с чтения csv данных
df = pd.read_csv('my_files/data.csv')

# %%
# Тестовый вывод двнных
df.head(10)
# Out:
#    age  income education_level  spending_score  job_title  salary  bonus  \
# 0   25   50000        Bachelor              75    Analyst   55000   5000
# 1   30   60000          Master              85    Manager   65000   7000
# 2   35   70000             PhD              95   Director   75000   9000
# 3   40   80000        Bachelor              80         VP   85000  12000
# 4   45   90000          Master              70  Executive   95000  15000
#
#    years_at_company  performance_score  department  hours_worked_per_week
# 0                 2                  8          HR                     40
# 1                 5                  9       Sales                     45
# 2                 7                 10     Finance                     50
# 3                10                  9          IT                     55
# 4                12                  8  Operations                     60

# %%
sns.relplot(x='age', y='spending_score', kind='line', data=df)

# %%
arr = ['age', 'income', 'years_at_company', 'hours_worked_per_week']
cor = sns.PairGrid(df[arr])
cor.map(sns.scatterplot)
